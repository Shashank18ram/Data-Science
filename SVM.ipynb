# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank18ram/Data-Science/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import google.colab
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('/content/Pharma_Industry.csv')
df.head()
# Out:
#    Drug Dosage (mg)  Systolic Blood Pressure (mmHg)  Heart Rate (BPM)  \
# 0         -0.128538                        0.303280         -1.881849
# 1         -1.846188                        2.865142         -0.929511
# 2         -1.252393                       -1.541613          0.363632
# 3          1.992515                       -1.142779         -0.766657
# 4          0.377100                        0.538410         -0.029263
#
#    Liver Toxicity Index (U/L)  Blood Glucose Level (mg/dL)  Drug Response
# 0                    0.258286                    -0.792011              1
# 1                    2.866786                    -0.719447              1
# 2                   -0.325370                     0.191314              0
# 3                    0.975286                    -0.823355              1
# 4                    1.896015                    -0.960130              1

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
x=df.drop('Drug Response',axis=1)
y=df['Drug Response']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
svm_model = SVC(kernel= 'linear',C=0.01)
svm_model.fit(x_train,y_train)
# Out:
# SVC(C=0.01, kernel='linear')

# %%
y_pred=svm_model.predict(x_test)
print(f'Accuracy Score: {accuracy_score(y_test,y_pred)}')
# Out:
# Accuracy Score: 0.76

# %%
svm_model.support_vectors_.shape
# Out:
# (326, 5)
