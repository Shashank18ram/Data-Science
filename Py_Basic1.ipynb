# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank18ram/Data-Science/blob/main/Py_Basic1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#this is single comment
x=1
y=2
z=x+y
print(z)
# Out:
# 3

# %%
#this is multiple comment in single line
x=3;y=4;z=x+y
print(z)
# Out:
# 7

# %%
#indentation example
if True:
  print("this will print")
  if False:
        print("this wont print")
  print("this might print")
print("this will also print")
# Out:
# this will print
# this might print
# this will also print

# %%
text=("Banana")
text=text.lower()
text=text.replace("a","O")
print(text)
# Out:
# bOnOnO

# %%
text= "Banana"
print(text.upper().replace("A","Z"))
# Out:
# BZNZNZ

# %%
#CASE SENSITIVE MATTERS IF UR GIVING CITIES NAME IN STARTING CAPS THEN ITS GONNA P IN RIGHT WAY
cities=["Bangalore","Jammu","Kashmir"]
print(max(cities))
# Out:
# Kashmir
