# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank18ram/Data-Science/blob/main/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('/content/banking_dataset.csv')
df.head()
# Out:
#    customer_age  account_balance  annual_income  loan_amount  \
# 0            56         17871.07     1131740.96    409401.23
# 1            69         54069.27      600090.95    188667.47
# 2            46         34872.99      756171.18    206035.43
# 3            32         21554.93      933147.71    318767.03
# 4            60         37068.54      345408.57    219029.55
#
#    loan_duration_months  num_of_credit_cards  credit_card_utilization  \
# 0                    51                    3                     0.84
# 1                    31                    1                     0.51
# 2                    13                    3                     0.53
# 3                    11                    2                     0.56
# 4                    29                    0                     0.17
#
#    monthly_salary  num_of_loans  num_of_defaults  ...  insurance_amount  \
# 0        54136.15             2                2  ...         128309.65
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   customer_age                 1000 non-null   int64
#  1   account_balance              1000 non-null   float64
#  2   annual_income                1000 non-null   float64
#  3   loan_amount                  1000 non-null   float64
#  4   loan_duration_months         1000 non-null   int64
#  5   num_of_credit_cards          1000 non-null   int64
#  6   credit_card_utilization      1000 non-null   float64
#  7   monthly_salary               1000 non-null   float64
#  8   num_of_loans                 1000 non-null   int64
#  9   num_of_defaults              1000 non-null   int64
#  10  num_of_transactions          1000 non-null   int64
#  11  avg_transaction_value        1000 non-null   float64
#  12  loan_to_income_ratio         1000 non-null   float64
# ...

# %%
from sklearn.preprocessing import StandardScaler
dfScaled=df.copy()

# %%
ss=StandardScaler()
scaled=ss.fit_transform(dfScaled.drop('bank_profit',axis=1))
scaled
# Out:
# array([[ 0.81295917, -1.69176366,  1.74294869, ..., -1.40825527,
#          0.5131844 ,  0.89327393],
#        [ 1.68057836,  0.14695336, -0.42963904, ...,  1.12371499,
#         -1.1784967 , -1.32724698],
#        [ 0.1455598 , -0.8281373 ,  0.20818281, ...,  1.79428246,
#         -0.72472812,  1.03205648],
#        ...,
#        [ 1.2133988 , -0.50416973,  0.68654228, ..., -0.83017987,
#         -0.27493997, -0.00881269],
#        [-0.5885795 ,  0.6741306 , -0.64032328, ...,  0.43580527,
#         -0.48988298, -0.59863856],
#        [ 0.74621924, -0.43851563,  1.73519873, ...,  0.37799772,
#          0.1788286 ,  1.24023032]])

# %%
df_scaled=pd.DataFrame(scaled,columns=dfScaled.drop('bank_profit',axis=1).columns)
df_scaled.head()
# Out:
#    customer_age  account_balance  annual_income  loan_amount  \
# 0      0.812959        -1.691764       1.742949     1.945064
# 1      1.680578         0.146953      -0.429639    -0.751237
# 2      0.145560        -0.828137       0.208183    -0.539084
# 3     -0.788799        -1.504639       0.931397     0.837951
# 4      1.079919        -0.716613      -1.470399    -0.380359
#
#    loan_duration_months  num_of_credit_cards  credit_card_utilization  \
# 0              0.642796             0.727699                 1.189854
# 1             -0.415392            -0.697764                 0.043626
# 2             -1.367761             0.727699                 0.113095
# 3             -1.473580             0.014967                 0.217297
# 4             -0.521211            -1.410495                -1.137336
#
#    monthly_salary  num_of_loans  num_of_defaults  ...  house_value  \
# 0       -0.317263      0.418966         1.258777  ...    -0.460125
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
dfMinMax=df.copy()

# %%
mm=MinMaxScaler()
scaled=mm.fit_transform(dfMinMax.drop('bank_profit',axis=1))
scaled
# Out:
# array([[0.74509804, 0.17410113, 0.75536169, ..., 0.07333333, 0.6325167 ,
#         0.75      ],
#        [1.        , 0.52674635, 0.40052073, ..., 0.80333333, 0.15924276,
#         0.11      ],
#        [0.54901961, 0.33973494, 0.50469388, ..., 0.99666667, 0.28619154,
#         0.79      ],
#        ...,
#        [0.8627451 , 0.40186827, 0.58282262, ..., 0.24      , 0.41202673,
#         0.49      ],
#        [0.33333333, 0.62785301, 0.36611043, ..., 0.605     , 0.3518931 ,
#         0.32      ],
#        [0.7254902 , 0.41445999, 0.75409591, ..., 0.58833333, 0.5389755 ,
#         0.85      ]])

# %%
df_Scaled=pd.DataFrame(scaled,columns=dfMinMax.drop('bank_profit',axis=1).columns)
df_Scaled.head()
# Out:
#    customer_age  account_balance  annual_income  loan_amount  \
# 0      0.745098         0.174101       0.755362     0.720454
# 1      1.000000         0.526746       0.400521     0.321579
# 2      0.549020         0.339735       0.504694     0.352963
# 3      0.274510         0.209990       0.622814     0.556674
# 4      0.823529         0.361124       0.230537     0.376444
#
#    loan_duration_months  num_of_credit_cards  credit_card_utilization  \
# 0              0.692308                 0.75                     0.84
# 1              0.384615                 0.25                     0.51
# 2              0.107692                 0.75                     0.53
# 3              0.076923                 0.50                     0.56
# 4              0.353846                 0.00                     0.17
#
#    monthly_salary  num_of_loans  num_of_defaults  ...  house_value  \
# 0        0.464366      0.666667              1.0  ...     0.486828
# ...

# %%
from sklearn.linear_model import LogisticRegression
#Import the classification  matrices
from sklearn.metrics import classification_report, confusion_matrix,roc_curve,roc_auc_score,accuracy_score

# %%
from sklearn.model_selection import ShuffleSplit,cross_validate
ss = ShuffleSplit(n_splits=10,test_size=0.2,random_state=42)
cv = cross_validate(lr,X,y,cv=ss,scoring='accuracy',return_train_score=True)
print(cv['test_score'].mean())
print(cv['train_score'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2729/2100608081.py in <cell line: 0>()
#       1 from sklearn.model_selection import ShuffleSplit,cross_validate
#       2 ss = ShuffleSplit(n_splits=10,test_size=0.2,random_state=42)
# ----> 3 cv = cross_validate(lr,X,y,cv=ss,scoring='accuracy',return_train_score=True)
#       4 print(cv['test_score'].mean())
#       5 print(cv['train_score'].mean())
#
# NameError: name 'X' is not defined

# %%
lr.fit(X,y)
y_pred_new = lr.predict(X)
print(accuracy_score(y,y_pred_new))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2729/1785735778.py in <cell line: 0>()
# ----> 1 lr.fit(X,y)
#       2 y_pred_new = lr.predict(X)
#       3 print(accuracy_score(y,y_pred_new))
#
# NameError: name 'X' is not defined

# %%
from sklearn.linear_model import LinearRegression,Lasso
lr=LinearRegression()
cv = cross_validate(lr,dfScaled,df['bank_profit'],cv=ss,scoring='r2',return_train_score=True)
print(cv['test_score'].mean())
print(cv['train_score'].mean())
# Out:
# 1.0
# 1.0

# %%
from sklearn.linear_model import LassoCV
lasso =LassoCV(cv=ss,random_state=42)

lassoCV=lasso.fit(dfScaled,df['bank_profit'])


lassoCV.alpha_
# Out:
# np.float64(18478780.84901518)

# %%
r2_train=lassoCV.score(dfScaled,df['bank_profit'])
print(f'R2 score for the best lasso model:{r2_train:.4F}')
# Out:
# R2 score for the best lasso model:1.0000
